# %% [markdown]
# # **Machine Learning with Python**

# %% [markdown]
# ## Exercise 1.2: Ethics and Direction of Machine Learning Programs

# %% [markdown]
# ### **Contents**

# %% [markdown]
# ##### 1) Importing libraries and data set
# ##### 2) Scaling
# ##### 2.1) Split first
# ##### 2.2) Date column: remove it from both sets
# ##### 2.3) Missing values
# ##### 2.4) Scaling

# %% [markdown]
# #### **1) Importing libraries and data set**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
# Setting up the path

path = r'C:\Users\andd0\Documents\Machine Learning with Python'

# %%
# Importing the data set

df = pd.read_csv(os.path.join(path, 'Main folder', '02 Data sets', 'Original data set', 'Dataset-weather-prediction-dataset-processed.csv'), index_col = False)

# %%
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# 1                 0             1.1  ...                     7
# 2                 0             0.0  ...                     7
# 3                 0             4.1  ...                     7
# 4                 0             5.4  ...                     3
#
#    VALENTIA_humidity  VALENTIA_pressure  VALENTIA_global_radiation  \
# 0               0.88             1.0003                       0.45
# 1               0.91             1.0007                       0.25
# 2               0.91             1.0096                       0.17
# 3               0.86             1.0184                       0.13
# 4               0.80             1.0328                       0.46
#
#    VALENTIA_precipitation  VALENTIA_snow_depth  VALENTIA_sunshine  \
# 0                    0.34                    0                4.7
# 1                    0.84                    0                0.7
# 2                    0.08                    0                0.1
# 3                    0.98                    0                0.0
# 4                    0.00                    0                5.7
#
#    VALENTIA_temp_mean  VALENTIA_temp_min  VALENTIA_temp_max
# 0                 8.5                6.0               10.9
# 1                 8.9                5.6               12.1
# 2                10.5                8.1               12.9
# 3                 7.4                7.3               10.6
# 4                 5.7                3.0                8.4
#
# [5 rows x 170 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 170 entries, DATE to VALENTIA_temp_max
# dtypes: float64(145), int64(25)
# memory usage: 29.8 MB

# %% [markdown]
# #### **2) Scaling**

# %% [markdown]
# #### 2.1 Split first

# %%
X_train, X_test = train_test_split(df, test_size=0.25, random_state=42)

# %% [markdown]
# #### 2.2 Date column: remove it from both sets

# %%
# Dropping the 'DATE' and 'MONTH' columns

X_train_nums = X_train.drop(columns=['DATE', 'MONTH'])
X_test_nums = X_test.drop(columns=['DATE', 'MONTH'])

# %% [markdown]
# #### 2.3 Missing values

# %%
X_train_nums.isnull().sum()
# Out:
# BASEL_cloud_cover         0
# BASEL_wind_speed          0
# BASEL_humidity            0
# BASEL_pressure            0
# BASEL_global_radiation    0
#                          ..
# VALENTIA_snow_depth       0
# VALENTIA_sunshine         0
# VALENTIA_temp_mean        0
# VALENTIA_temp_min         0
# VALENTIA_temp_max         0
# Length: 168, dtype: int64

# %%
X_test_nums.isnull().sum()
# Out:
# BASEL_cloud_cover         0
# BASEL_wind_speed          0
# BASEL_humidity            0
# BASEL_pressure            0
# BASEL_global_radiation    0
#                          ..
# VALENTIA_snow_depth       0
# VALENTIA_sunshine         0
# VALENTIA_temp_mean        0
# VALENTIA_temp_min         0
# VALENTIA_temp_max         0
# Length: 168, dtype: int64

# %% [markdown]
# #### 2.4 Scaling

# %%
# Create scaler object using StandardScaler from sklearn.preprocessing
# StandardScaler assumes data is normally distributed and scales with a distribution around 0 and standard deviation of 1 (task requirements). 
# Scaling happens independently with each variable.
# Fit scaler on training numeric part and transform both

scaler = StandardScaler()

# %%
# Create a new df with scaled data for both the train and test sets

X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train_nums),
                              columns=X_train_nums.columns, index=X_train_nums.index)

X_test_scaled = pd.DataFrame(scaler.fit_transform(X_test_nums),
                              columns=X_test_nums.columns, index=X_test_nums.index)

# %%
# Reattaching the date column
# This code allows me to place the 'DATE' column just after the index

date_train = X_train.pop('DATE')
X_train_scaled.insert(0, 'DATE', date_train)

date_test = X_test.pop('DATE')
X_test_scaled.insert(0, 'DATE', date_test)

# %%
# Train set

X_train_scaled.head()
# Out:
#            DATE  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 8196   19820610          -1.411077         -0.030950       -0.616603
# 20472  20160119           1.081862         -0.587893        0.557788
# 18269  20100107           0.666372         -0.866365        0.738464
# 7713   19810212          -1.411077         -0.030950       -0.164914
# 21958  20200213           0.666372          3.171473       -0.616603
#
#        BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 8196        -0.746131                1.181615            -0.321907
# 20472       -0.214102               -0.827240            -0.262136
# 18269       -1.262958               -1.009863            -0.301983
# 7713         0.409131               -0.590904            -0.441448
# 21958       -0.685328               -0.827240             1.909538
#
#        BASEL_snow_depth  BASEL_sunshine  BASEL_temp_mean  ...  \
# 8196          -0.178396        0.530475         1.352627  ...
# 20472         -0.178396       -1.069706        -1.652545  ...
# 18269          0.821457       -0.930560        -1.652545  ...
# 7713          -0.178396       -0.258020        -1.598397  ...
# 21958         -0.178396       -0.953751        -0.583137  ...
#
#        VALENTIA_cloud_cover  VALENTIA_humidity  VALENTIA_pressure  \
# 8196               0.169208           0.059797          -0.566890
# 20472             -0.443416          -0.080424          -0.007306
# 18269             -0.443416           1.041345           0.403055
# 7713               1.394457           1.181566          -1.033209
# 21958             -0.443416          -0.080424          -0.007306
#
#        VALENTIA_global_radiation  VALENTIA_precipitation  VALENTIA_snow_depth  \
# 8196                   -0.008427               -0.146880            -0.024111
# 20472                  -1.066874               -0.003704            -0.024111
# 18269                  -0.831663               -0.422219            -0.024111
# 7713                   -1.113916                1.284882            -0.024111
# 21958                  -0.008427               -0.003704            -0.024111
#
#        VALENTIA_sunshine  VALENTIA_temp_mean  VALENTIA_temp_min  \
# 8196           -0.411551            1.454750           1.575817
# 20472          -0.023323           -0.013908          -0.007755
# 18269          -0.083050           -2.921253          -3.229505
# 7713           -1.038689           -1.182841          -0.663026
# 21958          -0.023323           -0.013908          -0.007755
#
#        VALENTIA_temp_max
# 8196            1.165121
# 20472          -0.009817
# 18269          -2.187749
# 7713           -1.127440
# 21958          -0.009817
#
# [5 rows x 169 columns]

# %%
# Test set

X_test_scaled.head()
# Out:
#            DATE  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 19955  20140820           0.226971         -0.794596       -0.717731
# 7729   19810228           1.059150         -0.019585       -0.085363
# 10815  19890811           0.226971         -0.019585       -0.266040
# 3125   19680722          -0.605208         -0.019585       -0.898407
# 18985  20111224          -0.189118          2.047111        0.366328
#
#        BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 19955       -0.190473               -0.204771            -0.458106
# 7729        -0.781079               -1.159948             1.133485
# 10815       -0.905417                0.653815            -0.458106
# 3125        -0.003965                1.362149            -0.458106
# 18985        1.814479               -1.181413            -0.437701
#
#        BASEL_snow_depth  BASEL_sunshine  BASEL_temp_mean  ...  \
# 19955         -0.181705       -0.100121         0.651945  ...
# 7729          -0.181705       -1.052227        -1.254460  ...
# 10815         -0.181705       -0.193009         1.351417  ...
# 3125          -0.181705        0.828763         0.693090  ...
# 18985         -0.181705       -1.029004        -0.829290  ...
#
#        VALENTIA_cloud_cover  VALENTIA_humidity  VALENTIA_pressure  \
# 19955             -0.444564          -0.086364           0.006067
# 7729              -0.444564           0.197217          -2.787018
# 10815              0.786867           0.197217          -0.943582
# 3125               0.786867           0.622590           1.235024
# 18985             -0.444564          -0.086364           0.006067
#
#        VALENTIA_global_radiation  VALENTIA_precipitation  VALENTIA_snow_depth  \
# 19955                   1.070282               -0.014069            -0.026412
# 7729                   -0.517016                2.395530            -0.026412
# 10815                   1.176892               -0.563911            -0.026412
# 3125                    1.093973               -0.677114            -0.026412
# 18985                  -0.990836               -0.014069            -0.026412
#
#        VALENTIA_sunshine  VALENTIA_temp_mean  VALENTIA_temp_min  \
# 19955          -0.002957            0.012763           0.021267
# 7729           -0.706192           -1.470068          -1.239606
# 10815           0.547400            1.798212           1.994807
# 3125           -0.033533            1.283761           1.117678
# 18985          -0.002957            0.012763           0.021267
#
#        VALENTIA_temp_max
# 19955           0.011557
# 7729           -1.471135
# 10815           1.348887
# 3125            1.290742
# 18985           0.011557
#
# [5 rows x 169 columns]

# %%
# Exporting in CSV format

X_train_scaled.to_csv(os.path.join(path, 'Main folder', '02 Data sets', 'Prepared data set', 'X_train_scaled.csv'))
